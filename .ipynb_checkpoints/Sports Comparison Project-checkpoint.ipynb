# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os

# Tweet Counts

import requests
import json

# Set API Token
bearer_token = 'AAAAAAAAAAAAAAAAAAAAAJUlcAEAAAAAGfxL3e9FVRdqKSALsE1siSWr9p0%3DjfIbUoVwEiERdB4mf0AOTeGTQapwoiAJoxTbcA6Bnh1ZuFrOkz'
# Set Search URL
search_url = "https://api.twitter.com/2/tweets/counts/recent"

def bearer_oauth(r):
    """
    Method required by bearer token authentication.
    """

    r.headers["Authorization"] = f"Bearer {bearer_token}"
    r.headers["User-Agent"] = "v2RecentTweetCountsPython"
    return r


def connect_to_endpoint(url, params):
    response = requests.request("GET", search_url, auth=bearer_oauth, params=params)
    print(response.status_code)
    if response.status_code != 200:
        raise Exception(response.status_code, response.text)
    return response.json()

# %%
def main():
    
    # Overview
        # Read leagues and corresponding team names from excel spreadsheet
        # Make API Requests
        # Clean data
        # Store league data in separate Data Frames
        # Compare leagues
    
    # Organize league data
    
    # Premier League
    premier_league_data = pd.read_excel(open('Sports.xlsx', 'rb'),
              sheet_name="Premier League")
    global premier_league 
    premier_league = pd.DataFrame(premier_league_data, columns=["Premier League", "Hashtag", "Start Date", "End Date", "Day 0 Tweets", "Day 1 Tweets", "Day 2 Tweets", "Day 3 Tweets", "Day 4 Tweets", "Day 5 Tweets", "Day 6 Tweets", "Day 7 Tweets", "Total Tweets"])
    
    # NFL
    nfl_data = pd.read_excel(open('Sports.xlsx', 'rb'),
              sheet_name='NFL')
    global nfl
    nfl = pd.DataFrame(nfl_data, columns=["NFL", "Start Date", "End Date", "Day 0 Tweets", "Day 1 Tweets", "Day 2 Tweets", "Day 3 Tweets", "Day 4 Tweets", "Day 5 Tweets", "Day 6 Tweets", "Day 7 Tweets", "Total Tweets"])

    # MLB
    mlb_data = pd.read_excel(open('Sports.xlsx', 'rb'),
              sheet_name='MLB') 
    global mlb
    mlb = pd.DataFrame(mlb_data, columns=["MLB", "Start Date", "End Date", "Day 0 Tweets", "Day 1 Tweets", "Day 2 Tweets", "Day 3 Tweets", "Day 4 Tweets", "Day 5 Tweets", "Day 6 Tweets", "Day 7 Tweets", "Total Tweets"])

    # NBA
    nba_data = pd.read_excel(open('Sports.xlsx', 'rb'),
              sheet_name='NBA')
    global nba
    nba = pd.DataFrame(nba_data, columns=["NBA", "Start Date", "End Date", "Day 0 Tweets", "Day 1 Tweets", "Day 2 Tweets", "Day 3 Tweets", "Day 4 Tweets", "Day 5 Tweets", "Day 6 Tweets", "Day 7 Tweets", "Total Tweets"])

    # Loop through the Premier League
    for team in premier_league["Premier League"]:

        # Make API Request
        hashtag = premier_league.loc[premier_league["Premier League"] == team, "Hashtag"].item()
        hashtag = hashtag.replace(u'\xa0', u' ')
#         print(hashtag)
        query_params = {'query': hashtag, 'granularity': 'day'}
#         print(query_params)
        json_response = connect_to_endpoint(search_url, query_params)
        
        # Add data to the league data frame
        # Data includes start date, end data, tweet count for each day, overall tweet count
        premier_league.loc[premier_league["Premier League"] == team, "Start Date"] = json_response["data"][0]["start"]
        premier_league.loc[premier_league["Premier League"] == team, "End Date"] = json_response["data"][7]["end"]
        premier_league.loc[premier_league["Premier League"] == team, "Day 0 Tweets"] = json_response["data"][0]["tweet_count"]
        premier_league.loc[premier_league["Premier League"] == team, "Day 1 Tweets"] = json_response["data"][1]["tweet_count"]
        premier_league.loc[premier_league["Premier League"] == team, "Day 2 Tweets"] = json_response["data"][2]["tweet_count"]
        premier_league.loc[premier_league["Premier League"] == team, "Day 3 Tweets"] = json_response["data"][3]["tweet_count"]
        premier_league.loc[premier_league["Premier League"] == team, "Day 4 Tweets"] = json_response["data"][4]["tweet_count"]
        premier_league.loc[premier_league["Premier League"] == team, "Day 5 Tweets"] = json_response["data"][5]["tweet_count"]
        premier_league.loc[premier_league["Premier League"] == team, "Day 6 Tweets"] = json_response["data"][6]["tweet_count"]
        premier_league.loc[premier_league["Premier League"] == team, "Day 7 Tweets"] = json_response["data"][7]["tweet_count"]
        premier_league.loc[premier_league["Premier League"] == team, "Total Tweets"] = premier_league.loc[premier_league["Premier League"] == team, "Day 0 Tweets"] + premier_league.loc[premier_league["Premier League"] == team, "Day 1 Tweets"] + premier_league.loc[premier_league["Premier League"] == team, "Day 2 Tweets"] + premier_league.loc[premier_league["Premier League"] == team, "Day 3 Tweets"] + premier_league.loc[premier_league["Premier League"] == team, "Day 4 Tweets"] + premier_league.loc[premier_league["Premier League"] == team, "Day 5 Tweets"] + premier_league.loc[premier_league["Premier League"] == team, "Day 6 Tweets"] + premier_league.loc[premier_league["Premier League"] == team, "Day 7 Tweets"]

    # Loop through the NFL
    for team in nfl["NFL"]:
        
        # Make API Request
        query_params = {'query': team,'granularity': 'day'}
        json_response = connect_to_endpoint(search_url, query_params)

        # Add data to the league data frame
        # Data includes start date, end data, tweet count for each day, overall tweet count  
        nfl.loc[nfl["NFL"] == team, "Start Date"] = json_response["data"][0]["start"]
        nfl.loc[nfl["NFL"] == team, "End Date"] = json_response["data"][7]["end"]
        nfl.loc[nfl["NFL"] == team, "Day 0 Tweets"] = json_response["data"][0]["tweet_count"]
        nfl.loc[nfl["NFL"] == team, "Day 1 Tweets"] = json_response["data"][1]["tweet_count"]
        nfl.loc[nfl["NFL"] == team, "Day 2 Tweets"] = json_response["data"][2]["tweet_count"]
        nfl.loc[nfl["NFL"] == team, "Day 3 Tweets"] = json_response["data"][3]["tweet_count"]
        nfl.loc[nfl["NFL"] == team, "Day 4 Tweets"] = json_response["data"][4]["tweet_count"]
        nfl.loc[nfl["NFL"] == team, "Day 5 Tweets"] = json_response["data"][5]["tweet_count"]
        nfl.loc[nfl["NFL"] == team, "Day 6 Tweets"] = json_response["data"][6]["tweet_count"]
        nfl.loc[nfl["NFL"] == team, "Day 7 Tweets"] = json_response["data"][7]["tweet_count"]
        nfl.loc[nfl["NFL"] == team, "Total Tweets"] = nfl.loc[nfl["NFL"] == team, "Day 0 Tweets"] + nfl.loc[nfl["NFL"] == team, "Day 1 Tweets"] + nfl.loc[nfl["NFL"] == team, "Day 2 Tweets"] + nfl.loc[nfl["NFL"] == team, "Day 3 Tweets"] + nfl.loc[nfl["NFL"] == team, "Day 4 Tweets"] + nfl.loc[nfl["NFL"] == team, "Day 5 Tweets"] + nfl.loc[nfl["NFL"] == team, "Day 6 Tweets"] + nfl.loc[nfl["NFL"] == team, "Day 7 Tweets"]

    # Loop through the MLB
    for team in mlb["MLB"]:

        # Make API Request
        query_params = {'query': team,'granularity': 'day'}
        json_response = connect_to_endpoint(search_url, query_params)

        # Add data to the league data frame
        # Data includes start date, end data, tweet count for each day, overall tweet count
        mlb.loc[mlb["MLB"] == team, "Start Date"] = json_response["data"][0]["start"]
        mlb.loc[mlb["MLB"] == team, "End Date"] = json_response["data"][7]["end"]
        mlb.loc[mlb["MLB"] == team, "Day 0 Tweets"] = json_response["data"][0]["tweet_count"]
        mlb.loc[mlb["MLB"] == team, "Day 1 Tweets"] = json_response["data"][1]["tweet_count"]
        mlb.loc[mlb["MLB"] == team, "Day 2 Tweets"] = json_response["data"][2]["tweet_count"]
        mlb.loc[mlb["MLB"] == team, "Day 3 Tweets"] = json_response["data"][3]["tweet_count"]
        mlb.loc[mlb["MLB"] == team, "Day 4 Tweets"] = json_response["data"][4]["tweet_count"]
        mlb.loc[mlb["MLB"] == team, "Day 5 Tweets"] = json_response["data"][5]["tweet_count"]
        mlb.loc[mlb["MLB"] == team, "Day 6 Tweets"] = json_response["data"][6]["tweet_count"]
        mlb.loc[mlb["MLB"] == team, "Day 7 Tweets"] = json_response["data"][7]["tweet_count"]
        mlb.loc[mlb["MLB"] == team, "Total Tweets"] = mlb.loc[mlb["MLB"] == team, "Day 0 Tweets"] + mlb.loc[mlb["MLB"] == team, "Day 1 Tweets"] + mlb.loc[mlb["MLB"] == team, "Day 2 Tweets"] + mlb.loc[mlb["MLB"] == team, "Day 3 Tweets"] + mlb.loc[mlb["MLB"] == team, "Day 4 Tweets"] + mlb.loc[mlb["MLB"] == team, "Day 5 Tweets"] + mlb.loc[mlb["MLB"] == team, "Day 6 Tweets"] + mlb.loc[mlb["MLB"] == team, "Day 7 Tweets"]

    # Loop through the NBA
    for team in nba["NBA"]:

        # Make API Request
        query_params = {'query': team,'granularity': 'day'}
        json_response = connect_to_endpoint(search_url, query_params)

        # Add data to the league data frame
        # Data includes start date, end data, tweet count for each day, overall tweet count
        nba.loc[nba["NBA"] == team, "Start Date"] = json_response["data"][0]["start"]
        nba.loc[nba["NBA"] == team, "End Date"] = json_response["data"][7]["end"]
        nba.loc[nba["NBA"] == team, "Day 0 Tweets"] = json_response["data"][0]["tweet_count"]
        nba.loc[nba["NBA"] == team, "Day 1 Tweets"] = json_response["data"][1]["tweet_count"]
        nba.loc[nba["NBA"] == team, "Day 2 Tweets"] = json_response["data"][2]["tweet_count"]
        nba.loc[nba["NBA"] == team, "Day 3 Tweets"] = json_response["data"][3]["tweet_count"]
        nba.loc[nba["NBA"] == team, "Day 4 Tweets"] = json_response["data"][4]["tweet_count"]
        nba.loc[nba["NBA"] == team, "Day 5 Tweets"] = json_response["data"][5]["tweet_count"]
        nba.loc[nba["NBA"] == team, "Day 6 Tweets"] = json_response["data"][6]["tweet_count"]
        nba.loc[nba["NBA"] == team, "Day 7 Tweets"] = json_response["data"][7]["tweet_count"]
        nba.loc[nba["NBA"] == team, "Total Tweets"] = nba.loc[nba["NBA"] == team, "Day 0 Tweets"] + nba.loc[nba["NBA"] == team, "Day 1 Tweets"] + nba.loc[nba["NBA"] == team, "Day 2 Tweets"] + nba.loc[nba["NBA"] == team, "Day 3 Tweets"] +nba.loc[nba["NBA"] == team, "Day 4 Tweets"] + nba.loc[nba["NBA"] == team, "Day 5 Tweets"] +nba.loc[nba["NBA"] == team, "Day 6 Tweets"] + nba.loc[nba["NBA"] == team, "Day 7 Tweets"]
      
if __name__ == "__main__":
    main()
# Out:
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200

# %%
# Display the data
display(premier_league)
display(nfl)
display(mlb)
display(nba)
# Out:
#              Premier League            Hashtag                Start Date  \
# 0           Manchester City          @ManCity   2022-04-27T01:26:56.000Z
# 1                 Liverpool               @LFC  2022-04-27T01:26:57.000Z
# 2                   Chelsea        @ChelseaFC   2022-04-27T01:26:57.000Z
# 3                   Arsenal          @Arsenal   2022-04-27T01:26:57.000Z
# 4         Tottenham Hotspur    @SpursOfficial   2022-04-27T01:26:57.000Z
# 5         Manchester United            @ManUtd  2022-04-27T01:26:57.000Z
# 6           West Ham United          @WestHam   2022-04-27T01:26:57.000Z
# 7   Wolverhampton Wanderers    @WolvesAcademy   2022-04-27T01:26:58.000Z
# 8      Brighton Hove Albion    @OfficialBHAFC   2022-04-27T01:26:58.000Z
# 9          Newcastle United             @NUFC   2022-04-27T01:26:58.000Z
# 10           Leicester City             @LCFC   2022-04-27T01:26:58.000Z
# 11           Crystal Palace             @CPFC   2022-04-27T01:26:58.000Z
# ...

# %%
# Create pie chart
premier_league_total = premier_league["Total Tweets"].sum()

nfl_total = nfl["Total Tweets"].sum()

mlb_total = mlb["Total Tweets"].sum()

nba_total = nba["Total Tweets"].sum()

# %%
# Create pie chart to show how values are relative to eachother

# Labels for the sections of our pie chart
labels = ["Premier League", "NFL", "MLB", "NBA"]

# The values of each section of the pie chart
sizes = [premier_league_total, nfl_total, mlb_total, nba_total]

# The colors of each section of the pie chart
colors = ["red", "orange", "lightcoral", "lightskyblue"]

# Tells matplotlib to separate the "Humans" section from the others
explode = (0, 0, 0, 0.1)

# Creates the pie chart based upon the values above
# Automatically finds the percentages of each part of the pie chart
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=140)
# Out:
# ([<matplotlib.patches.Wedge at 0x7ff3ad3f0100>,
# ...
#  [Text(-0.7996848639186651, -0.755317230320735, 'Premier League'),
#   Text(1.0548489956725748, 0.31191921442668513, 'NFL'),
#   Text(-0.08984875901652556, 1.096324404774057, 'MLB'),
#   Text(-0.6283885067766007, 1.0223149634780244, 'NBA')],
#  [Text(-0.4361917439556355, -0.41199121653858267, '46.3%'),
#   Text(0.575372179457768, 0.17013775332364642, '38.7%'),
#   Text(-0.049008414009013936, 0.5979951298767583, '4.7%'),
#   Text(-0.36655996228635035, 0.5963503953621809, '10.2%')])

# %%
# Save data to excel

# Create graphs
    # Seven day graphs for each league comparing teams
    # Totals in bar chart comparing teams in leagues
    # Totals in bar chart comparing totals for each leagues  
    
# Premier League team comparison
premier_league = premier_league.sort_values(by=["Total Tweets"])
x_axis= np.arange(len(premier_league))
tick_locations = [value+0.4 for value in x_axis]
plt.bar(x_axis, premier_league["Total Tweets"], color='r', alpha=0.5, align="edge")
plt.xticks(tick_locations, premier_league["Premier League"], rotation="vertical")
plt.title("Premier League Clubs' Tweet Totals (Past Seven Days)")
plt.xlabel("Club")
plt.ylabel("Amount of Tweets")

print("The average amount of tweets per team in the Premier League is " + str(premier_league["Total Tweets"].mean()))

# NFL League team comparison
nfl = nfl.sort_values(by=["Total Tweets"])
x_axis= np.arange(len(nfl))
tick_locations = [value+0.4 for value in x_axis]
plt.bar(x_axis, nfl["Total Tweets"], color='r', alpha=0.5, align="edge")
plt.xticks(tick_locations, nfl["NFL"], rotation="vertical")
plt.title("NFL Teams' Tweet Totals (Past Seven Days)")
plt.xlabel("Team")
plt.ylabel("Amount of Tweets")

print("The average amount of tweets per team in the NFL is " + str(nfl["Total Tweets"].mean()))
print(nfl["Total Tweets"])
display(nfl)


# # MLB League team comparison
# mlb = mlb.sort_values(by=["Total Tweets"])
# x_axis= np.arange(len(mlb))
# tick_locations = [value+0.4 for value in x_axis]
# plt.bar(x_axis, mlb["Total Tweets"], color='r', alpha=0.5, align="edge")
# plt.xticks(tick_locations, mlb["MLB"], rotation="vertical")
# plt.title("MLB Teams' Tweet Totals (Past Seven Days)")
# plt.xlabel("Team")
# plt.ylabel("Amount of Tweets")

# # NBA League team comparison
# nba = nba.sort_values(by=["Total Tweets"])
# x_axis= np.arange(len(nba))
# tick_locations = [value+0.4 for value in x_axis]
# plt.bar(x_axis, nba["Total Tweets"], color='r', alpha=0.5, align="edge")
# plt.xticks(tick_locations, nba["NBA"], rotation="vertical")
# plt.title("NBA Teams' Tweet Totals (Past Seven Days)")
# plt.xlabel("Team")
# plt.ylabel("Amount of Tweets")
# Out:
# The average amount of tweets per team in the Premier League is 71400.6
# The average amount of tweets per team in the NFL is nan
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 5    NaN
# 6    NaN
# 7    NaN
# 8    NaN
# 9    NaN
# 10   NaN
# 11   NaN
# 12   NaN
# 13   NaN
# 14   NaN
# 15   NaN
# 16   NaN
# 17   NaN
# 18   NaN
# 19   NaN
# 20   NaN
# 21   NaN
# 22   NaN
# 23   NaN
# 24   NaN
# 25   NaN
# 26   NaN
# 27   NaN
# 28   NaN
# 29   NaN
# 30   NaN
# 31   NaN
# Name: Total Tweets, dtype: float64
#                      NFL  Start Date  End Date  Day 0 Tweets  Day 1 Tweets  \
# 0          Buffalo Bills         NaN       NaN           NaN           NaN
# 1   New England Patriots         NaN       NaN           NaN           NaN
# 2         Miami Dolphins         NaN       NaN           NaN           NaN
# 3          New York Jets         NaN       NaN           NaN           NaN
# 4     Cincinnati Bengals         NaN       NaN           NaN           NaN
# ...

# %%
google_trends_data = pd.read_csv('multiTimeline.csv')
google_trends = pd.DataFrame(google_trends_data)
display(google_trends)
# Out:
#               Time  mlb: (Worldwide)  nba: (Worldwide)  nfl: (Worldwide)  \
# 0    2022-04-26T18                15                65                 5
# 1    2022-04-26T19                16                78                 4
# 2    2022-04-26T20                12                54                 4
# 3    2022-04-26T21                 8                50                 3
# 4    2022-04-26T22                 4                26                 2
# ..             ...               ...               ...               ...
# 163  2022-05-03T13                 5                11                 2
# 164  2022-05-03T14                 6                16                 3
# 165  2022-05-03T15                 9                25                 3
# 166  2022-05-03T16                12                47                 3
# 167  2022-05-03T17                15                59                 3
#
#      premier league: (Worldwide)
# 0                              2
# ...

# %%
premier_league_total = google_trends["premier league: (Worldwide)"].sum()
print(premier_league_total / 7 / 24)

nfl_total = google_trends["nfl: (Worldwide)"].sum()
print(nfl_total / 7 / 24)

mlb_total = google_trends["mlb: (Worldwide)"].sum()
print(mlb_total / 7 / 24)

nba_total = google_trends["nba: (Worldwide)"].sum()
print(nba_total / 7 / 24)
# Out:
# 7.416666666666667
# 9.988095238095239
# 5.7559523809523805
# 21.523809523809522

# %%
# Create pie chart to show how values are relative to eachother

# Labels for the sections of our pie chart
labels = ["Premier League", "NFL", "MLB", "NBA"]

# The values of each section of the pie chart
sizes = [premier_league_total, nfl_total, mlb_total, nba_total]

# The colors of each section of the pie chart
colors = ["red", "orange", "lightcoral", "lightskyblue"]

# Tells matplotlib to separate the "Humans" section from the others
explode = (0, 0, 0, 0.1)

# Creates the pie chart based upon the values above
# Automatically finds the percentages of each part of the pie chart
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=140)
# Out:
# ([<matplotlib.patches.Wedge at 0x7ff3adc5ba60>,
# ...
#  [Text(-1.082872987951741, 0.19335483434470746, 'Premier League'),
#   Text(-0.5502215020421465, -0.952500025559309, 'NFL'),
#   Text(0.6056487332048914, -0.9182535662698569, 'MLB'),
#   Text(0.7172019347801936, 0.9620921913972419, 'NBA')],
#  [Text(-0.5906579934282222, 0.10546627327893134, '16.6%'),
#   Text(-0.30012081929571627, -0.5195454684868958, '22.4%'),
#   Text(0.3303538544753953, -0.50086558160174, '12.9%'),
#   Text(0.41836779528844625, 0.5612204449817244, '48.2%')])
